# %%
VS <- read.csv("~/project-ionic/R/week7/Vacation Spending II.csv")

# %%
head (VS)
# Out:
#   Income Age NumChildren HousePrice MonthlyRestaurant MonthlyEntertainment
# 1 150000 32  3           1505600    300               221
# 2  60000 41  0            627770    127               185
# 3 120000 58  2           1217166    300                54
# 4 180000 59  4           1821064    480               126
# 5 165000 54  3           1674000    452               220
# 6  70000 26  2            712082    162               109
#   Spending
# 1 12388
# 2  6042
# 3 10395
# 4 14547
# 5 14051
# 6  6540

# %%
library(psych)
pairs.panels(VS[,-8], 
             method = "pearson", # correlation method
             hist.col = "#00AFBB",
             density = TRUE,  # show density plots
             ellipses = TRUE # show correlation ellipses
)
# Out:
# plot without title

# %%
mod1 <- lm(Spending~Income, data = VS)
summary(mod1)
# Out:
# Call:
# lm(formula = Spending ~ Income, data = VS)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -1327.9  -649.5  -401.3   292.1  6984.0
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept) 3.532e+03  7.275e+02   4.855 4.12e-05 ***
# Income      6.194e-02  4.583e-03  13.516 8.57e-14 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 1507 on 28 degrees of freedom
# Multiple R-squared:  0.8671,	Adjusted R-squared:  0.8623
# F-statistic: 182.7 on 1 and 28 DF,  p-value: 8.569e-14

# %%
mod2 <- lm(Spending~HousePrice, data = VS)
summary(mod2)
# Out:
# Call:
# lm(formula = Spending ~ HousePrice, data = VS)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -1990.0 -1030.2  -721.7   364.5 11787.9
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept) 4.549e+03  1.238e+03   3.676 0.000995 ***
# HousePrice  5.548e-03  7.900e-04   7.023 1.23e-07 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 2488 on 28 degrees of freedom
# Multiple R-squared:  0.6379,	Adjusted R-squared:  0.6249
# F-statistic: 49.32 on 1 and 28 DF,  p-value: 1.226e-07

# %%
mod3 <- lm(Spending~ MonthlyEntertainment, data = VS)
summary(mod3)
# Out:
# Call:
# lm(formula = Spending ~ MonthlyEntertainment, data = VS)
#
# Residuals:
#    Min     1Q Median     3Q    Max
#  -6604  -2855  -1466   4079   6520
#
# Coefficients:
#                       Estimate Std. Error t value Pr(>|t|)
# (Intercept)          12544.503   1804.310   6.953 1.47e-07 ***
# MonthlyEntertainment     0.551     10.112   0.054    0.957
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 4134 on 28 degrees of freedom
# Multiple R-squared:  0.000106,	Adjusted R-squared:  -0.0356
# F-statistic: 0.002969 on 1 and 28 DF,  p-value: 0.9569

# %%
mod4 <- lm(Spending~Income, data = VS)
summary(mod4)
# Out:
# Call:
# lm(formula = Spending ~ Income, data = VS)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -1327.9  -649.5  -401.3   292.1  6984.0
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept) 3.532e+03  7.275e+02   4.855 4.12e-05 ***
# Income      6.194e-02  4.583e-03  13.516 8.57e-14 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 1507 on 28 degrees of freedom
# Multiple R-squared:  0.8671,	Adjusted R-squared:  0.8623
# F-statistic: 182.7 on 1 and 28 DF,  p-value: 8.569e-14

# %%
mod5 <- lm(Spending~NumChildren, data = VS)
summary(mod5)
# Out:
# Call:
# lm(formula = Spending ~ NumChildren, data = VS)
#
# Residuals:
#    Min     1Q Median     3Q    Max
#  -6651  -2836  -1458   4092   6591
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept) 12692.91    1338.06   9.486 3.04e-10 ***
# NumChildren   -29.55     552.43  -0.053    0.958
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 4134 on 28 degrees of freedom
# Multiple R-squared:  0.0001022,	Adjusted R-squared:  -0.03561
# F-statistic: 0.002862 on 1 and 28 DF,  p-value: 0.9577

# %%
modT <- lm(Spending~., data = VS)
summary(modT)
# Out:
# Call:
# lm(formula = Spending ~ ., data = VS)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -1148.5  -847.2   -89.3   392.3  3683.2
#
# Coefficients:
#                        Estimate Std. Error t value Pr(>|t|)
# (Intercept)           3.287e+03  1.213e+03   2.709   0.0125 *
# Income                4.202e-02  7.355e-03   5.712 8.12e-06 ***
# Age                  -1.908e+01  1.988e+01  -0.960   0.3472
# NumChildren          -2.435e+02  1.734e+02  -1.404   0.1737
# HousePrice            1.207e-03  6.372e-04   1.894   0.0708 .
# MonthlyRestaurant     6.588e+00  2.583e+00   2.550   0.0179 *
# MonthlyEntertainment  2.723e+00  3.098e+00   0.879   0.3885
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 1197 on 23 degrees of freedom
# Multiple R-squared:  0.9311,	Adjusted R-squared:  0.9131
# F-statistic:  51.8 on 6 and 23 DF,  p-value: 3.231e-12

# %% [markdown]
# fornula = (3.287e+03) + (4.202e-02* income)+ (6.588e+00 * MonthlyResturant)
