# %%
import pandas as pd
import numpy as np
import geopandas as gp
import matplotlib.pyplot as plt
from pandas import DataFrame, Series
crimes = pd.read_csv("../week8crime/report.csv")
# %matplotlib inline

# %%
type(crimes)
# Out:
# pandas.core.frame.DataFrame

# %%
crimes.columns
# Out:
# Index(['report_year', 'agency_code', 'agency_jurisdiction', 'population',
#        'violent_crimes', 'homicides', 'rapes', 'assaults', 'robberies',
#        'months_reported', 'crimes_percapita', 'homicides_percapita',
#        'rapes_percapita', 'assaults_percapita', 'robberies_percapita'],
#       dtype='object')

# %%
crimes.head()
# Out:
#    report_year agency_code agency_jurisdiction  population  violent_crimes  \
# 0         1975     NM00101     Albuquerque, NM    286238.0          2383.0
# 1         1975     TX22001       Arlington, TX    112478.0           278.0
# 2         1975     GAAPD00         Atlanta, GA    490584.0          8033.0
# 3         1975     CO00101          Aurora, CO    116656.0           611.0
# 4         1975     TX22701          Austin, TX    300400.0          1215.0
#
#    homicides  rapes  assaults  robberies  months_reported  crimes_percapita  \
# 0       30.0  181.0    1353.0      819.0             12.0            832.52
# 1        5.0   28.0     132.0      113.0             12.0            247.16
# 2      185.0  443.0    3518.0     3887.0             12.0           1637.44
# 3        7.0   44.0     389.0      171.0             12.0            523.76
# 4       33.0  190.0     463.0      529.0             12.0            404.46
#
# ...

# %%
crimes.tail()
# Out:
#       report_year agency_code agency_jurisdiction  population  violent_crimes  \
# 2824         2015     OK07205           Tulsa, OK    401520.0          3628.0
# 2825         2015     VA12800  Virginia Beach, VA    452797.0           626.0
# 2826         2015     DCMPD00      Washington, DC    672228.0          8084.0
# 2827         2015     KS08703         Wichita, KS    389824.0          3839.0
# 2828         2015         NaN       United States         NaN       1197704.0
#
#       homicides  rapes  assaults  robberies  months_reported  \
# 2824       55.0  365.0    2354.0      854.0              NaN
# 2825       19.0  103.0     234.0      270.0              NaN
# 2826      162.0  494.0    4024.0     3404.0              NaN
# 2827       27.0  349.0    2730.0      733.0              NaN
# 2828    15696.0    NaN       NaN        NaN              NaN
#
#       crimes_percapita  homicides_percapita  rapes_percapita  \
# 2824            903.57                13.70            90.90
# ...

# %%
crimes.dtypes
# Out:
# report_year              int64
# agency_code             object
# agency_jurisdiction     object
# population             float64
# violent_crimes         float64
# homicides              float64
# rapes                  float64
# assaults               float64
# robberies              float64
# months_reported        float64
# crimes_percapita       float64
# homicides_percapita    float64
# rapes_percapita        float64
# assaults_percapita     float64
# robberies_percapita    float64
# dtype: object

# %%
crimes.shape
# Out:
# (2829, 15)

# %%
by_j=crimes["agency_jurisdiction"].head()

# %%
type(by_j)
# Out:
# pandas.core.series.Series

# %%
crimes1 = pd.read_csv("../week8crime/report.csv", index_col=2)

# %%
crimes1.head()
# Out:
#                      report_year agency_code  population  violent_crimes  \
# agency_jurisdiction
# Albuquerque, NM             1975     NM00101    286238.0          2383.0
# Arlington, TX               1975     TX22001    112478.0           278.0
# Atlanta, GA                 1975     GAAPD00    490584.0          8033.0
# Aurora, CO                  1975     CO00101    116656.0           611.0
# Austin, TX                  1975     TX22701    300400.0          1215.0
#
#                      homicides  rapes  assaults  robberies  months_reported  \
# agency_jurisdiction
# Albuquerque, NM           30.0  181.0    1353.0      819.0             12.0
# Arlington, TX              5.0   28.0     132.0      113.0             12.0
# Atlanta, GA              185.0  443.0    3518.0     3887.0             12.0
# Aurora, CO                 7.0   44.0     389.0      171.0             12.0
# Austin, TX                33.0  190.0     463.0      529.0             12.0
#
# ...

# %%
crimes1.loc["Aurora, CO"]
# Out:
#                      report_year agency_code  population  violent_crimes  \
# agency_jurisdiction
# Aurora, CO                  1975     CO00101    116656.0           611.0
# Aurora, CO                  1976     CO00101    132000.0           546.0
# Aurora, CO                  1977     CO00101    137200.0           585.0
# Aurora, CO                  1978     CO00101    131499.0           831.0
# Aurora, CO                  1979     CO00101    134224.0          1033.0
# Aurora, CO                  1980     CO00101    158249.0          1278.0
# Aurora, CO                  1981     CO00101    162900.0          1437.0
# Aurora, CO                  1982     CO00101    167408.0          1406.0
# Aurora, CO                  1983     CO00101    172575.0          1706.0
# Aurora, CO                  1984     CO00101    191159.0          1822.0
# Aurora, CO                  1985     CO00101    198033.0          2250.0
# Aurora, CO                  1986     CO00101    200189.0          2868.0
# ...

# %%
crimes1.loc[ "Aurora, CO" , ["population","violent_crimes"]]
# Out:
#                      population  violent_crimes
# agency_jurisdiction
# Aurora, CO             116656.0           611.0
# Aurora, CO             132000.0           546.0
# Aurora, CO             137200.0           585.0
# Aurora, CO             131499.0           831.0
# Aurora, CO             134224.0          1033.0
# Aurora, CO             158249.0          1278.0
# Aurora, CO             162900.0          1437.0
# Aurora, CO             167408.0          1406.0
# Aurora, CO             172575.0          1706.0
# Aurora, CO             191159.0          1822.0
# Aurora, CO             198033.0          2250.0
# Aurora, CO             200189.0          2868.0
# Aurora, CO             219945.0          2700.0
# Aurora, CO             219404.0          2625.0
# Aurora, CO             219780.0          2859.0
# Aurora, CO             222103.0          3191.0
# Aurora, CO             227670.0          3746.0
# Aurora, CO             233939.0          4064.0
# ...

# %%
crimes1.loc[crimes1.population > 500000, ["population","violent_crimes"]]
# Out:
#                             population  violent_crimes
# agency_jurisdiction
# Baltimore County, MD          642154.0          1259.0
# Baltimore, MD                 864100.0         16086.0
# Boston, MA                    616120.0         11386.0
# Chicago, IL                  3150000.0         37160.0
# Cleveland, OH                 659931.0         10403.0
# Columbus, OH                  572797.0          3980.0
# Dallas, TX                    864665.0          7655.0
# Denver, CO                    508140.0          4960.0
# Detroit, MI                  1432444.0         30387.0
# Honolulu, HI                  705262.0          1596.0
# Houston, TX                  1372342.0          8924.0
# Indianapolis, IN              503411.0          4655.0
# Jacksonville, FL              542792.0          4579.0
# Los Angeles County, CA       1022888.0          9792.0
# Los Angeles, CA              2729878.0         30405.0
# Memphis, TN                   646483.0          5429.0
# ...
